# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install kdtree
# Out:
# Collecting kdtree
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: kdtree
# Successfully installed kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #units = "metric"
    #city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

    city_url = f"{url}q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng =city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | saynshand
# Processing Record 3 of Set 1 | gadzhiyevo
# Processing Record 4 of Set 1 | ancud
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | waiuku
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | alofi
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | nemuro
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | qaqortoq
# Processing Record 15 of Set 1 | richards bay
# Processing Record 16 of Set 1 | bykovo
# Processing Record 17 of Set 1 | polyarnyy
# Processing Record 18 of Set 1 | kholmskiy
# Processing Record 19 of Set 1 | callao
# Processing Record 20 of Set 1 | wailua homesteads
# Processing Record 21 of Set 1 | rongelap
# Processing Record 22 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 23 of Set 1 | edd
# Processing Record 24 of Set 1 | nova vicosa
# Processing Record 25 of Set 1 | nyurba
# Processing Record 26 of Set 1 | ola
# Processing Record 27 of Set 1 | waitangi
# Processing Record 28 of Set 1 | divo
# Processing Record 29 of Set 1 | suva
# Processing Record 30 of Set 1 | puerto natales
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | papatowai
# Processing Record 33 of Set 1 | usogorsk
# Processing Record 34 of Set 1 | machico
# Processing Record 35 of Set 1 | merizo village
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | stanley
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | la passe
# Processing Record 41 of Set 1 | iskateley
# Processing Record 42 of Set 1 | ponoka
# Processing Record 43 of Set 1 | belyy yar
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | bakri
# Processing Record 46 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 47 of Set 1 | la'ie
# Processing Record 48 of Set 1 | cockburn town
# Processing Record 49 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 50 of Set 1 | port-aux-francais
# Processing Record 0 of Set 2 | saipan
# Processing Record 1 of Set 2 | bandarbeyla
# Processing Record 2 of Set 2 | margaret river
# Processing Record 3 of Set 2 | olonkinbyen
# Processing Record 4 of Set 2 | howard springs
# Processing Record 5 of Set 2 | kingston
# Processing Record 6 of Set 2 | abepura
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | anadyr
# Processing Record 9 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 10 of Set 2 | east ballina
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | cova figueira
# Processing Record 13 of Set 2 | invercargill
# Processing Record 14 of Set 2 | west island
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | ta`u
# Processing Record 17 of Set 2 | praia da vitoria
# Processing Record 18 of Set 2 | blackmans bay
# Processing Record 19 of Set 2 | neiafu
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | vadso
# Processing Record 23 of Set 2 | al bardiyah
# Processing Record 24 of Set 2 | lihue
# Processing Record 25 of Set 2 | makar'yev
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | conceicao do araguaia
# Processing Record 28 of Set 2 | mezhdurechenskiy
# Processing Record 29 of Set 2 | quellon
# Processing Record 30 of Set 2 | dudinka
# Processing Record 31 of Set 2 | songea
# Processing Record 32 of Set 2 | bilibino
# Processing Record 33 of Set 2 | nkurenkuru
# City not found. Skipping...
# Processing Record 34 of Set 2 | seminole
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | kolonia town
# Processing Record 37 of Set 2 | puerto madero
# Processing Record 38 of Set 2 | malakal
# Processing Record 39 of Set 2 | kapa'a
# Processing Record 40 of Set 2 | laojunmiao
# Processing Record 41 of Set 2 | springbok
# Processing Record 42 of Set 2 | lata
# Processing Record 43 of Set 2 | bamboo flat
# Processing Record 44 of Set 2 | barra do bugres
# Processing Record 45 of Set 2 | port mathurin
# Processing Record 46 of Set 2 | badger
# Processing Record 47 of Set 2 | chambersburg
# Processing Record 48 of Set 2 | pisco
# Processing Record 49 of Set 2 | lubumbashi
# Processing Record 0 of Set 3 | barinas
# Processing Record 1 of Set 3 | dowlatabad
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | as sulaymaniyah
# Processing Record 4 of Set 3 | inarajan village
# Processing Record 5 of Set 3 | villa aldama
# Processing Record 6 of Set 3 | san pedro
# Processing Record 7 of Set 3 | vorgashor
# Processing Record 8 of Set 3 | queenstown
# Processing Record 9 of Set 3 | muzayri'
# City not found. Skipping...
# Processing Record 10 of Set 3 | edinburgh of the seven seas
# Processing Record 11 of Set 3 | san fernando de apure
# Processing Record 12 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 13 of Set 3 | macapa
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | inyonga
# Processing Record 16 of Set 3 | conde-sur-noireau
# Processing Record 17 of Set 3 | st. john's
# Processing Record 18 of Set 3 | kimbe
# Processing Record 19 of Set 3 | flekkefjord
# Processing Record 20 of Set 3 | kirensk
# Processing Record 21 of Set 3 | tazovsky
# Processing Record 22 of Set 3 | taunggyi
# Processing Record 23 of Set 3 | ushuaia
# Processing Record 24 of Set 3 | sao gabriel da cachoeira
# Processing Record 25 of Set 3 | juneau
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | belogorsk
# Processing Record 28 of Set 3 | kirakira
# Processing Record 29 of Set 3 | nizhnyaya omka
# Processing Record 30 of Set 3 | victoria point
# Processing Record 31 of Set 3 | barakani
# Processing Record 32 of Set 3 | udachny
# Processing Record 33 of Set 3 | nuuk
# Processing Record 34 of Set 3 | fuman
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | the pas
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | qamdo
# Processing Record 39 of Set 3 | kargil
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | aripuana
# Processing Record 42 of Set 3 | codrington
# Processing Record 43 of Set 3 | clorinda
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | malaba
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | bikenibeu village
# Processing Record 48 of Set 3 | sars
# Processing Record 49 of Set 3 | mishkino
# Processing Record 0 of Set 4 | litovel
# Processing Record 1 of Set 4 | letlhakeng
# Processing Record 2 of Set 4 | pitiquito
# Processing Record 3 of Set 4 | onsala
# Processing Record 4 of Set 4 | salinopolis
# Processing Record 5 of Set 4 | as sulayyil
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | wynyard
# Processing Record 8 of Set 4 | pacasmayo
# Processing Record 9 of Set 4 | mount gambier
# Processing Record 10 of Set 4 | tromso
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | hawaiian paradise park
# Processing Record 14 of Set 4 | antalaha
# Processing Record 15 of Set 4 | inirida
# Processing Record 16 of Set 4 | hadibu
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | tobruk
# Processing Record 19 of Set 4 | galeana
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | fort-de-france
# Processing Record 22 of Set 4 | ust-nera
# Processing Record 23 of Set 4 | boden
# Processing Record 24 of Set 4 | fale old settlement
# Processing Record 25 of Set 4 | nadym
# Processing Record 26 of Set 4 | laguna
# Processing Record 27 of Set 4 | enewetak
# Processing Record 28 of Set 4 | west gulfport
# Processing Record 29 of Set 4 | goz beida
# Processing Record 30 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 4 | harnai
# Processing Record 32 of Set 4 | huarmey
# Processing Record 33 of Set 4 | port blair
# Processing Record 34 of Set 4 | mamboma
# Processing Record 35 of Set 4 | san antonio de pale
# Processing Record 36 of Set 4 | calvinia
# Processing Record 37 of Set 4 | cambridge
# Processing Record 38 of Set 4 | mirnyy
# Processing Record 39 of Set 4 | eket
# Processing Record 40 of Set 4 | santanyi
# Processing Record 41 of Set 4 | boguchany
# Processing Record 42 of Set 4 | hastings
# Processing Record 43 of Set 4 | buala
# Processing Record 44 of Set 4 | estancia velha
# Processing Record 45 of Set 4 | saudarkrokur
# Processing Record 46 of Set 4 | constantia
# Processing Record 47 of Set 4 | avarua
# Processing Record 48 of Set 4 | sandakan
# Processing Record 49 of Set 4 | mili
# Processing Record 0 of Set 5 | kone
# Processing Record 1 of Set 5 | susuman
# Processing Record 2 of Set 5 | magadan
# Processing Record 3 of Set 5 | nazret
# Processing Record 4 of Set 5 | fort bragg
# Processing Record 5 of Set 5 | micheweni
# Processing Record 6 of Set 5 | viedma
# Processing Record 7 of Set 5 | lubao
# Processing Record 8 of Set 5 | galle
# Processing Record 9 of Set 5 | waat
# Processing Record 10 of Set 5 | tangalle
# Processing Record 11 of Set 5 | bouca
# Processing Record 12 of Set 5 | poronaysk
# Processing Record 13 of Set 5 | ulladulla
# Processing Record 14 of Set 5 | khandyga
# Processing Record 15 of Set 5 | zhoushan
# Processing Record 16 of Set 5 | siwa oasis
# Processing Record 17 of Set 5 | villa gesell
# Processing Record 18 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 5 | port alfred
# Processing Record 20 of Set 5 | robore
# Processing Record 21 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 5 | luimneach
# Processing Record 23 of Set 5 | yerofey pavlovich
# Processing Record 24 of Set 5 | taltal
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | goronyo
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | brookings
# Processing Record 29 of Set 5 | sassandra
# Processing Record 30 of Set 5 | isafjordur
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | hyesan
# Processing Record 33 of Set 5 | troitskoye
# Processing Record 34 of Set 5 | palmer
# Processing Record 35 of Set 5 | whitehorse
# Processing Record 36 of Set 5 | kendari
# Processing Record 37 of Set 5 | antofagasta
# Processing Record 38 of Set 5 | bich'vinta
# Processing Record 39 of Set 5 | zouerate
# Processing Record 40 of Set 5 | bonthe
# Processing Record 41 of Set 5 | siliana
# Processing Record 42 of Set 5 | dalandzadgad
# Processing Record 43 of Set 5 | santa cruz
# Processing Record 44 of Set 5 | kiato
# Processing Record 45 of Set 5 | marsh harbour
# Processing Record 46 of Set 5 | nar'yan-mar
# Processing Record 47 of Set 5 | takamaka
# City not found. Skipping...
# Processing Record 48 of Set 5 | beja
# Processing Record 49 of Set 5 | asheboro
# Processing Record 0 of Set 6 | longyearbyen
# Processing Record 1 of Set 6 | cudahy
# Processing Record 2 of Set 6 | khorugh
# Processing Record 3 of Set 6 | ambodifotatra
# Processing Record 4 of Set 6 | laascaanood
# Processing Record 5 of Set 6 | fortaleza
# Processing Record 6 of Set 6 | kigoma
# Processing Record 7 of Set 6 | bel ombre
# Processing Record 8 of Set 6 | rong kwang
# Processing Record 9 of Set 6 | tsiombe
# Processing Record 10 of Set 6 | qashyr
# Processing Record 11 of Set 6 | sao felix do xingu
# Processing Record 12 of Set 6 | aykol
# City not found. Skipping...
# Processing Record 13 of Set 6 | dakhla
# Processing Record 14 of Set 6 | dadonghai
# City not found. Skipping...
# Processing Record 15 of Set 6 | henderson
# Processing Record 16 of Set 6 | benguela
# Processing Record 17 of Set 6 | aasiaat
# Processing Record 18 of Set 6 | nantucket
# Processing Record 19 of Set 6 | andovoranto
# Processing Record 20 of Set 6 | dondo
# Processing Record 21 of Set 6 | lindsay
# Processing Record 22 of Set 6 | portland
# Processing Record 23 of Set 6 | daru
# Processing Record 24 of Set 6 | shuangcheng
# Processing Record 25 of Set 6 | newman
# Processing Record 26 of Set 6 | t'ongch'on-up
# Processing Record 27 of Set 6 | wotje
# Processing Record 28 of Set 6 | maibong
# Processing Record 29 of Set 6 | grand baie
# Processing Record 30 of Set 6 | kapuskasing
# Processing Record 31 of Set 6 | tolanaro
# Processing Record 32 of Set 6 | kerikeri
# Processing Record 33 of Set 6 | cajati
# Processing Record 34 of Set 6 | egilsstadir
# Processing Record 35 of Set 6 | sao joao da barra
# Processing Record 36 of Set 6 | monte argentario
# Processing Record 37 of Set 6 | imperatriz
# Processing Record 38 of Set 6 | delijan
# Processing Record 39 of Set 6 | bredasdorp
# Processing Record 40 of Set 6 | atafu village
# Processing Record 41 of Set 6 | utrik
# Processing Record 42 of Set 6 | bam
# Processing Record 43 of Set 6 | whakatane
# Processing Record 44 of Set 6 | norilsk
# Processing Record 45 of Set 6 | karratha
# Processing Record 46 of Set 6 | mil'kovo
# Processing Record 47 of Set 6 | huntsville
# Processing Record 48 of Set 6 | pont rouge
# Processing Record 49 of Set 6 | masterton
# Processing Record 0 of Set 7 | guanica
# Processing Record 1 of Set 7 | fort st. john
# Processing Record 2 of Set 7 | alaghsas
# Processing Record 3 of Set 7 | port saint john's
# Processing Record 4 of Set 7 | pyay
# Processing Record 5 of Set 7 | maragogi
# Processing Record 6 of Set 7 | port elizabeth
# Processing Record 7 of Set 7 | rikaze
# Processing Record 8 of Set 7 | nogliki
# Processing Record 9 of Set 7 | ypsonas
# Processing Record 10 of Set 7 | capao da canoa
# Processing Record 11 of Set 7 | hauterive
# Processing Record 12 of Set 7 | bardai
# Processing Record 13 of Set 7 | grand falls-windsor
# Processing Record 14 of Set 7 | klazienaveen
# Processing Record 15 of Set 7 | greenville
# Processing Record 16 of Set 7 | longfeng
# Processing Record 17 of Set 7 | shelton
# Processing Record 18 of Set 7 | port-saint-louis-du-rhone
# Processing Record 19 of Set 7 | xifeng
# Processing Record 20 of Set 7 | al qusiyah
# Processing Record 21 of Set 7 | margate
# Processing Record 22 of Set 7 | timbuktu
# Processing Record 23 of Set 7 | belmonte
# Processing Record 24 of Set 7 | puerto deseado
# Processing Record 25 of Set 7 | jamestown
# Processing Record 26 of Set 7 | papao
# Processing Record 27 of Set 7 | orange cove
# Processing Record 28 of Set 7 | kayangel
# Processing Record 29 of Set 7 | warner robins
# Processing Record 30 of Set 7 | aldama
# Processing Record 31 of Set 7 | vila velha
# Processing Record 32 of Set 7 | sur
# Processing Record 33 of Set 7 | constitucion
# Processing Record 34 of Set 7 | fuerte olimpo
# Processing Record 35 of Set 7 | klyuchi
# Processing Record 36 of Set 7 | chistopol'
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | jabor
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | thisted
# Processing Record 41 of Set 7 | launceston
# Processing Record 42 of Set 7 | uturoa
# Processing Record 43 of Set 7 | portales
# Processing Record 44 of Set 7 | marquelia
# Processing Record 45 of Set 7 | jayapura
# Processing Record 46 of Set 7 | dordrecht
# Processing Record 47 of Set 7 | beaconsfield
# Processing Record 48 of Set 7 | marudi
# City not found. Skipping...
# Processing Record 49 of Set 7 | west plains
# Processing Record 0 of Set 8 | gladstone
# Processing Record 1 of Set 8 | weno
# Processing Record 2 of Set 8 | ad dilam
# Processing Record 3 of Set 8 | la sarre
# Processing Record 4 of Set 8 | rioja
# Processing Record 5 of Set 8 | tura
# Processing Record 6 of Set 8 | tshabong
# Processing Record 7 of Set 8 | tevragh zeina
# City not found. Skipping...
# Processing Record 8 of Set 8 | jonuta
# Processing Record 9 of Set 8 | torghay
# Processing Record 10 of Set 8 | talcahuano
# Processing Record 11 of Set 8 | aykhal
# Processing Record 12 of Set 8 | antsohimbondrona
# City not found. Skipping...
# Processing Record 13 of Set 8 | fiambala
# Processing Record 14 of Set 8 | manaure
# Processing Record 15 of Set 8 | opuwo
# Processing Record 16 of Set 8 | castillos
# Processing Record 17 of Set 8 | palapag
# Processing Record 18 of Set 8 | aurich
# Processing Record 19 of Set 8 | gueltat zemmour
# City not found. Skipping...
# Processing Record 20 of Set 8 | cherepovets
# Processing Record 21 of Set 8 | knyaze-volkonskoye
# Processing Record 22 of Set 8 | vila do maio
# Processing Record 23 of Set 8 | bure
# Processing Record 24 of Set 8 | muncar
# Processing Record 25 of Set 8 | severo-vostotchnyi bank
# Processing Record 26 of Set 8 | kzyltu
# Processing Record 27 of Set 8 | tempoal de sanchez
# Processing Record 28 of Set 8 | bakchar
# Processing Record 29 of Set 8 | general conesa
# Processing Record 30 of Set 8 | crucecita
# Processing Record 31 of Set 8 | yanbu
# Processing Record 32 of Set 8 | kill devil hills
# Processing Record 33 of Set 8 | cobija
# Processing Record 34 of Set 8 | nova sintra
# Processing Record 35 of Set 8 | gwanda
# Processing Record 36 of Set 8 | upington
# Processing Record 37 of Set 8 | ardakan
# Processing Record 38 of Set 8 | carutapera
# Processing Record 39 of Set 8 | redencao
# Processing Record 40 of Set 8 | yatou
# Processing Record 41 of Set 8 | fisterra
# Processing Record 42 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 43 of Set 8 | mitu
# Processing Record 44 of Set 8 | wodonga
# Processing Record 45 of Set 8 | tarija
# Processing Record 46 of Set 8 | afaahiti
# Processing Record 47 of Set 8 | waingapu
# Processing Record 48 of Set 8 | sokoni
# Processing Record 49 of Set 8 | ganye
# Processing Record 0 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 1 of Set 9 | tadine
# Processing Record 2 of Set 9 | aral
# Processing Record 3 of Set 9 | gore
# Processing Record 4 of Set 9 | saint-tropez
# Processing Record 5 of Set 9 | panaba
# Processing Record 6 of Set 9 | santa cruz de tenerife
# Processing Record 7 of Set 9 | haiku-pauwela
# Processing Record 8 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 9 of Set 9 | saint croix
# Processing Record 10 of Set 9 | ulsteinvik
# Processing Record 11 of Set 9 | manatutu
# City not found. Skipping...
# Processing Record 12 of Set 9 | mount pearl
# Processing Record 13 of Set 9 | kavaratti
# Processing Record 14 of Set 9 | rio grande
# Processing Record 15 of Set 9 | ust'-kalmanka
# Processing Record 16 of Set 9 | amherst
# Processing Record 17 of Set 9 | reguiba
# Processing Record 18 of Set 9 | hammerfest
# Processing Record 19 of Set 9 | yarkovo
# Processing Record 20 of Set 9 | howrah
# Processing Record 21 of Set 9 | san-pedro
# Processing Record 22 of Set 9 | tchintabaraden
# Processing Record 23 of Set 9 | cooper's town
# Processing Record 24 of Set 9 | totness
# Processing Record 25 of Set 9 | saldanha
# Processing Record 26 of Set 9 | mambusao
# Processing Record 27 of Set 9 | rio claro
# Processing Record 28 of Set 9 | lekki
# City not found. Skipping...
# Processing Record 29 of Set 9 | puerto santa
# Processing Record 30 of Set 9 | gaillac
# Processing Record 31 of Set 9 | cidreira
# Processing Record 32 of Set 9 | bhuban
# Processing Record 33 of Set 9 | walvis bay
# Processing Record 34 of Set 9 | businga
# Processing Record 35 of Set 9 | damghan
# Processing Record 36 of Set 9 | sitka
# Processing Record 37 of Set 9 | angaur state
# Processing Record 38 of Set 9 | hancheng
# Processing Record 39 of Set 9 | genhe
# Processing Record 40 of Set 9 | wenling
# Processing Record 41 of Set 9 | svendborg
# Processing Record 42 of Set 9 | darwin
# Processing Record 43 of Set 9 | tierp
# Processing Record 44 of Set 9 | puerto san jose
# Processing Record 45 of Set 9 | ad dabbah
# Processing Record 46 of Set 9 | vaijapur
# Processing Record 47 of Set 9 | we
# City not found. Skipping...
# Processing Record 48 of Set 9 | horta
# Processing Record 49 of Set 9 | dwarka
# Processing Record 0 of Set 10 | mandalgovi
# Processing Record 1 of Set 10 | el granada
# Processing Record 2 of Set 10 | salekhard
# Processing Record 3 of Set 10 | hailun
# Processing Record 4 of Set 10 | ephrata
# Processing Record 5 of Set 10 | touros
# Processing Record 6 of Set 10 | akom ii
# Processing Record 7 of Set 10 | gorontalo
# Processing Record 8 of Set 10 | taksimo
# Processing Record 9 of Set 10 | valparaiso
# Processing Record 10 of Set 10 | thurso
# Processing Record 11 of Set 10 | taoudenni
# Processing Record 12 of Set 10 | venancio aires
# Processing Record 13 of Set 10 | elek
# Processing Record 14 of Set 10 | roma
# Processing Record 15 of Set 10 | labuan
# Processing Record 16 of Set 10 | saham
# Processing Record 17 of Set 10 | lao cai
# Processing Record 18 of Set 10 | urangan
# Processing Record 19 of Set 10 | orange
# Processing Record 20 of Set 10 | isangel
# Processing Record 21 of Set 10 | qarqaraly
# Processing Record 22 of Set 10 | tamanrasset
# Processing Record 23 of Set 10 | muar
# Processing Record 24 of Set 10 | siliguri
# Processing Record 25 of Set 10 | vilyuchinsk
# Processing Record 26 of Set 10 | nago
# Processing Record 27 of Set 10 | uji
# Processing Record 28 of Set 10 | aracuai
# Processing Record 29 of Set 10 | kattivakkam
# Processing Record 30 of Set 10 | la ronge
# Processing Record 31 of Set 10 | hobyo
# Processing Record 32 of Set 10 | winnemucca
# Processing Record 33 of Set 10 | mejit
# Processing Record 34 of Set 10 | lazaro cardenas
# Processing Record 35 of Set 10 | kesinga
# Processing Record 36 of Set 10 | trinidad
# Processing Record 37 of Set 10 | punta del este
# Processing Record 38 of Set 10 | al jawf
# Processing Record 39 of Set 10 | sodankyla
# Processing Record 40 of Set 10 | mahriz
# Processing Record 41 of Set 10 | el charco
# Processing Record 42 of Set 10 | broken hill
# Processing Record 43 of Set 10 | fada
# Processing Record 44 of Set 10 | barcelos
# Processing Record 45 of Set 10 | dhidhdhoo
# Processing Record 46 of Set 10 | lagos
# Processing Record 47 of Set 10 | laibin
# Processing Record 48 of Set 10 | flying fish cove
# Processing Record 49 of Set 10 | yanai
# Processing Record 0 of Set 11 | archangelos
# Processing Record 1 of Set 11 | hailar
# Processing Record 2 of Set 11 | zavodskoy
# Processing Record 3 of Set 11 | camacupa
# Processing Record 4 of Set 11 | gulf shores
# Processing Record 5 of Set 11 | antsiranana
# Processing Record 6 of Set 11 | crane
# Processing Record 7 of Set 11 | chenzhou
# Processing Record 8 of Set 11 | strathalbyn
# Processing Record 9 of Set 11 | susanville
# Processing Record 10 of Set 11 | okhotsk
# Processing Record 11 of Set 11 | kasane
# Processing Record 12 of Set 11 | seria
# Processing Record 13 of Set 11 | sao francisco
# Processing Record 14 of Set 11 | igarka
# Processing Record 15 of Set 11 | ouani
# Processing Record 16 of Set 11 | quebo
# Processing Record 17 of Set 11 | akureyri
# Processing Record 18 of Set 11 | port shepstone
# Processing Record 19 of Set 11 | kailua-kona
# Processing Record 20 of Set 11 | baza
# Processing Record 21 of Set 11 | jacksonville
# Processing Record 22 of Set 11 | siracusa
# Processing Record 23 of Set 11 | ironwood
# Processing Record 24 of Set 11 | neftegorsk
# Processing Record 25 of Set 11 | keflavik
# Processing Record 26 of Set 11 | yinchuan
# Processing Record 27 of Set 11 | imbituba
# Processing Record 28 of Set 11 | christchurch
# Processing Record 29 of Set 11 | mushie
# Processing Record 30 of Set 11 | olds
# Processing Record 31 of Set 11 | kanchanaburi
# Processing Record 32 of Set 11 | lockwood
# Processing Record 33 of Set 11 | linxia chengguanzhen
# Processing Record 34 of Set 11 | okha
# Processing Record 35 of Set 11 | marang
# Processing Record 36 of Set 11 | mogocha
# Processing Record 37 of Set 11 | ndioum
# Processing Record 38 of Set 11 | nagqu
# Processing Record 39 of Set 11 | labytnangi
# Processing Record 40 of Set 11 | black point
# Processing Record 41 of Set 11 | hrebinka
# Processing Record 42 of Set 11 | gizo
# Processing Record 43 of Set 11 | lake munmorah
# Processing Record 44 of Set 11 | shahr sultan
# Processing Record 45 of Set 11 | watertown
# Processing Record 46 of Set 11 | north battleford
# Processing Record 47 of Set 11 | port hedland
# Processing Record 48 of Set 11 | mikuni
# Processing Record 49 of Set 11 | geraldton
# Processing Record 0 of Set 12 | kerewan
# Processing Record 1 of Set 12 | jaru
# Processing Record 2 of Set 12 | loukhi
# Processing Record 3 of Set 12 | remire-montjoly
# Processing Record 4 of Set 12 | peiting
# Processing Record 5 of Set 12 | pathein
# Processing Record 6 of Set 12 | marshfield
# Processing Record 7 of Set 12 | nampula
# Processing Record 8 of Set 12 | lerwick
# Processing Record 9 of Set 12 | idri
# Processing Record 10 of Set 12 | selfoss
# Processing Record 11 of Set 12 | bafra
# Processing Record 12 of Set 12 | turabah
# Processing Record 13 of Set 12 | songjiang
# Processing Record 14 of Set 12 | sao vicente
# Processing Record 15 of Set 12 | san lorenzo de esmeraldas
# Processing Record 16 of Set 12 | hola
# Processing Record 17 of Set 12 | prudnik
# Processing Record 18 of Set 12 | sola
# Processing Record 19 of Set 12 | tobelo
# Processing Record 20 of Set 12 | gidam
# Processing Record 21 of Set 12 | marion
# Processing Record 22 of Set 12 | takoradi
# Processing Record 23 of Set 12 | happy valley-goose bay
# Processing Record 24 of Set 12 | sakaiminato
# Processing Record 25 of Set 12 | kudat
# Processing Record 26 of Set 12 | porto barra do ivinheima
# Processing Record 27 of Set 12 | dunedin
# Processing Record 28 of Set 12 | puerto cortez
# Processing Record 29 of Set 12 | bereznik
# Processing Record 30 of Set 12 | dongola
# Processing Record 31 of Set 12 | sinabang
# Processing Record 32 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 12 | san fernando
# Processing Record 34 of Set 12 | yen vinh
# Processing Record 35 of Set 12 | merritt
# Processing Record 36 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 37 of Set 12 | at-bashi
# Processing Record 38 of Set 12 | motueka
# Processing Record 39 of Set 12 | birao
# Processing Record 40 of Set 12 | manokwari
# Processing Record 41 of Set 12 | yanchep
# Processing Record 42 of Set 12 | arinos
# Processing Record 43 of Set 12 | mata-utu
# Processing Record 44 of Set 12 | reggane
# Processing Record 45 of Set 12 | tateyama
# Processing Record 46 of Set 12 | murun-kuren
# Processing Record 47 of Set 12 | kittila
# Processing Record 48 of Set 12 | novodvinsk
# Processing Record 49 of Set 12 | khurba
# Processing Record 0 of Set 13 | conception bay south
# Processing Record 1 of Set 13 | devinuwara
# City not found. Skipping...
# Processing Record 2 of Set 13 | hood river
# Processing Record 3 of Set 13 | mana
# Processing Record 4 of Set 13 | tucurui
# Processing Record 5 of Set 13 | shenjiamen
# Processing Record 6 of Set 13 | plastun
# Processing Record 7 of Set 13 | kulia village
# City not found. Skipping...
# Processing Record 8 of Set 13 | robertsport
# Processing Record 9 of Set 13 | wau
# Processing Record 10 of Set 13 | dryden
# Processing Record 11 of Set 13 | hinton
# Processing Record 12 of Set 13 | kralendijk
# Processing Record 13 of Set 13 | naze
# Processing Record 14 of Set 13 | itamaraca
# Processing Record 15 of Set 13 | mukalla
# Processing Record 16 of Set 13 | tralee
# Processing Record 17 of Set 13 | bubaque
# Processing Record 18 of Set 13 | caleta de carquin
# Processing Record 19 of Set 13 | brisas de zicatela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          594
# Lat           594
# Lng           594
# Max Temp      594
# Humidity      594
# Cloudiness    594
# Wind Speed    594
# Country       594
# Date          594
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      albany  42.6001  -73.9662    296.38        89          31        1.03
# 1   saynshand  44.8824  110.1163    296.61        28           0        1.65
# 2  gadzhiyevo  69.2551   33.3362    286.67        82         100        0.51
# 3       ancud -41.8697  -73.8203    282.48        71          38        6.61
# 4   adamstown -25.0660 -130.1015    294.75        78          37        5.83
#
#   Country        Date
# 0      US  1689389831
# 1      MN  1689390065
# 2      RU  1689390066
# 3      CL  1689390066
# 4      PN  1689390066

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            albany  42.6001  -73.9662    296.38        89          31
# 1         saynshand  44.8824  110.1163    296.61        28           0
# 2        gadzhiyevo  69.2551   33.3362    286.67        82         100
# 3             ancud -41.8697  -73.8203    282.48        71          38
# 4         adamstown -25.0660 -130.1015    294.75        78          37
#
#          Wind Speed Country        Date
# City_ID
# 0              1.03      US  1689389831
# 1              1.65      MN  1689390065
# 2              0.51      RU  1689390066
# 3              6.61      CL  1689390066
# 4              5.83      PN  1689390066

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.6, edgecolors='k')

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-07-14)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperatur (C)")
plt.grid(True)
plt.tight_layout

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.6, edgecolors='k')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2023-07-14)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.tight_layout

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.6, edgecolors='k')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2023-07-14)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.tight_layout
# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.6, edgecolors='k')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-07-14)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)
plt.tight_layout
# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df=city_data_df.loc[pd.to_numeric(city_data_df["Lat"])>=0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            albany  42.6001  -73.9662    296.38        89          31
# 1         saynshand  44.8824  110.1163    296.61        28           0
# 2        gadzhiyevo  69.2551   33.3362    286.67        82         100
# 7           iqaluit  63.7506  -68.5145    280.00       100          75
# 11           nemuro  43.3236  145.5750    286.81        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.03      US  1689389831
# 1              1.65      MN  1689390065
# 2              0.51      RU  1689390066
# 7              0.00      CA  1689390013
# 11             3.57      JP  1689390052

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[pd.to_numeric(city_data_df["Lat"])<0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3            ancud -41.8697  -73.8203    282.48        71          38
# 4        adamstown -25.0660 -130.1015    294.75        78          37
# 5        grytviken -54.2811  -36.5092    268.63        57           0
# 6           waiuku -37.2500  174.7500    288.89        86          29
# 8         hermanus -34.4187   19.2345    286.87        72           1
#
#          Wind Speed Country        Date
# City_ID
# 3              6.61      CL  1689390066
# 4              5.83      PN  1689390066
# 5              2.05      GS  1689390067
# 6              3.99      NZ  1689390067
# 8              4.46      ZA  1689390068

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.6184230420551632

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.7519257451329718

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.08059724168071533

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.1377797456301726

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.07757399915467

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.15824407267636503

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.08648187793950624

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.020101356218227222

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
1. there does not seem to be a correlation between wind speed and latitude.
2. The higher the latitude, the lower the temperature
3. The humidity seems to be higher, the lower the latitude
4. the tempreature seems to rise the closer the cities are to the equator.
